# %% [markdown]
# <a href="https://colab.research.google.com/github/Irfann24/TugasMachineLearning/blob/main/Tugas_Pertemuan_2_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Aktivitas Api di New South Wales, Australia
# *Data diambil secara manual.*
# *Sumber: https://developer.ibm.com/exchanges/data/all/spot-challenge-wildfires/*

# %%
import pandas as pd
dataset = "/content/NSW_Wildfires_Temperature.csv"
data = pd.read_csv(dataset)
data
# Out:
#      Region_x     Date_x  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0         NSW   1/4/2005                26.04                      312.266667
# 1         NSW   1/5/2005               132.89                      322.475000
# 2         NSW   1/6/2005                16.56                      325.266667
# 3         NSW   1/7/2005                31.32                      313.870000
# 4         NSW   1/8/2005                16.20                      337.383333
# ...       ...        ...                  ...                             ...
# 4533      NSW  6/19/2020                 1.32                      305.350000
# 4534      NSW  6/25/2020                 1.32                      304.250000
# 4535      NSW  6/26/2020                 4.00                      312.575000
# 4536      NSW  6/29/2020                 2.08                      304.450000
# 4537      NSW  6/30/2020                 1.80                      304.050000
#
# ...

# %%
data.head(9)
# Out:
#   Region_x     Date_x  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0      NSW   1/4/2005                26.04                      312.266667
# 1      NSW   1/5/2005               132.89                      322.475000
# 2      NSW   1/6/2005                16.56                      325.266667
# 3      NSW   1/7/2005                31.32                      313.870000
# 4      NSW   1/8/2005                16.20                      337.383333
# 5      NSW   1/9/2005                96.05                      314.757143
# 6      NSW  1/10/2005               182.88                      324.800000
# 7      NSW  1/11/2005               524.55                      318.446875
# 8      NSW  1/12/2005               214.32                      323.238462
#
#    Mean_estimated_fire_radiative_power  Mean_confidence  Std_confidence  \
# 0                            42.400000        78.666667        2.886751
# 1                            62.362500        85.500000        8.088793
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Date_x']
  ys = series['Mean_estimated_fire_brightness']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_12.sort_values('Date_x', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('Region_y')):
  _plot_series(series, series_name, i)
  fig.legend(title='Region_y', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Date_x')
_ = plt.ylabel('Mean_estimated_fire_brightness')

# %%
print(data.dtypes)
# Out:
# Region_x                                object
# Date_x                                  object
# Estimated_fire_area                    float64
# Mean_estimated_fire_brightness         float64
# Mean_estimated_fire_radiative_power    float64
# Mean_confidence                        float64
# Std_confidence                         float64
# Var_confidence                         float64
# Count                                    int64
# Replaced                                object
# DateTime                                object
# Date_y                                  object
# Region_y                                object
# Parameter                               object
# count()[unit: km^2]                    float64
# min()                                  float64
# max()                                  float64
# mean()                                 float64
# 2nd moment                             float64
# dtype: object

# %%
datamiss = data.drop(data.columns[5],axis=1)
datamiss
# Out:
#      Region_x     Date_x  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0         NSW   1/4/2005                26.04                      312.266667
# 1         NSW   1/5/2005               132.89                      322.475000
# 2         NSW   1/6/2005                16.56                      325.266667
# 3         NSW   1/7/2005                31.32                      313.870000
# 4         NSW   1/8/2005                16.20                      337.383333
# ...       ...        ...                  ...                             ...
# 4533      NSW  6/19/2020                 1.32                      305.350000
# 4534      NSW  6/25/2020                 1.32                      304.250000
# 4535      NSW  6/26/2020                 4.00                      312.575000
# 4536      NSW  6/29/2020                 2.08                      304.450000
# 4537      NSW  6/30/2020                 1.80                      304.050000
#
# ...

# %%
data.describe()
# Out:
#        Estimated_fire_area  Mean_estimated_fire_brightness  \
# count         4.538000e+03                     4538.000000
# mean          2.253521e+04                      315.607445
# std           3.568487e+05                        8.766026
# min           1.000000e+00                      290.700000
# 25%           1.394000e+01                      309.539489
# 50%           9.185500e+01                      314.886184
# 75%           5.854950e+02                      320.897917
# max           1.441640e+07                      373.812500
#
#        Mean_estimated_fire_radiative_power  Mean_confidence  Std_confidence  \
# count                          4538.000000      4538.000000     3999.000000
# mean                             66.823031        86.167305        6.786112
# std                              57.948250         4.750099        2.526437
# min                               7.200000        76.000000        0.000000
# ...

# %%
data.loc[:,"Estimated_fire_area":].corr()
# Out:
# <ipython-input-10-1038c933fd00>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"Estimated_fire_area":].corr()
#                                      Estimated_fire_area  \
# Estimated_fire_area                             1.000000
# Mean_estimated_fire_brightness                  0.084184
# Mean_estimated_fire_radiative_power             0.093414
# Mean_confidence                                 0.109027
# Std_confidence                                  0.007537
# Var_confidence                                 -0.003784
# Count                                           0.884317
# count()[unit: km^2]                                  NaN
# min()                                           0.039923
# max()                                           0.071541
# ...

# %% [markdown]
# #Data Indikator Ekonomi di Brazil
# *Data diambil dari kaggle dengan metode API.*

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-93c5c761-6ce9-4abd-8da8-26d5e90cead3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93c5c761-6ce9-4abd-8da8-26d5e90cead3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "stocks market dataset"
# Out:
# ...
# ref                                                         title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rohanrao/nifty50-stock-market-data                          NIFTY-50 Stock Market Data (2000 - 2021)             18MB  2021-05-01 09:23:17          60912        770  1.0
# camnugent/sandp500                                          S&P 500 stock data                                   19MB  2018-02-10 03:15:53          74183       1006  0.7647059
# cnic92/200-financial-indicators-of-us-stocks-20142018       200+ Financial Indicators of US stocks (2014-2018)   15MB  2020-01-18 17:16:22          13797        264  0.9705882
# ...

# %%
# !kaggle datasets download andrewmvd/brazilian-stock-market
# Out:
# ...
#  82% 14.0M/17.1M [00:00<00:00, 65.3MB/s]
# 100% 17.1M/17.1M [00:00<00:00, 72.4MB/s]

# %%
# !unzip brazilian-stock-market.zip
# Out:
# Archive:  brazilian-stock-market.zip
#   inflating: bovespa_indexes.csv
#   inflating: bovespa_stocks.csv
#   inflating: economic_indicators.csv

# %%
import pandas as pd
dataset2 = "/content/economic_indicators.csv"
data2 = pd.read_csv(dataset2)
data2
# Out:
#             Date  Taxa Selic  IPCA  IGP-M  INPC  Desemprego PNADC
# 0     2010-01-01        8.75  0.75   0.63  0.88               NaN
# 1     2010-01-02        8.75   NaN    NaN   NaN               NaN
# 2     2010-01-03        8.75   NaN    NaN   NaN               NaN
# 3     2010-01-04        8.75   NaN    NaN   NaN               NaN
# 4     2010-01-05        8.75   NaN    NaN   NaN               NaN
# ...          ...         ...   ...    ...   ...               ...
# 5170  2024-02-27       11.25   NaN    NaN   NaN               NaN
# 5171  2024-02-28       11.25   NaN    NaN   NaN               NaN
# 5172  2024-02-29       11.25   NaN    NaN   NaN               NaN
# 5173  2024-03-01       11.25   NaN    NaN   NaN               NaN
# 5174  2024-03-02       11.25   NaN    NaN   NaN               NaN
#
# [5175 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
from matplotlib import pyplot as plt
data2['IPCA'].plot(kind='hist', bins=20, title='IPCA')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data2.describe()
# Out:
#         Taxa Selic        IPCA       IGP-M        INPC  Desemprego PNADC
# count  5175.000000  169.000000  170.000000  169.000000        142.000000
# mean      9.539710    0.482722    0.604824    0.483905         10.309859
# std       3.547022    0.366679    0.919608    0.397997          2.602599
# min       2.000000   -0.680000   -1.930000   -0.600000          6.300000
# 25%       6.500000    0.250000    0.150000    0.190000          7.800000
# 50%      10.250000    0.460000    0.535000    0.470000         11.100000
# 75%      12.500000    0.730000    0.947500    0.710000         12.400000
# max      14.250000    1.620000    4.340000    1.710000         14.900000

# %%
print(data2.dtypes)
# Out:
# Date                 object
# Taxa Selic          float64
# IPCA                float64
# IGP-M               float64
# INPC                float64
# Desemprego PNADC    float64
# dtype: object

# %%
data2.loc[:,"Taxa Selic":].corr()
# Out:
#                   Taxa Selic      IPCA     IGP-M      INPC  Desemprego PNADC
# Taxa Selic          1.000000 -0.001681 -0.460461 -0.037939         -0.535693
# IPCA               -0.001681  1.000000  0.398003  0.966987         -0.077979
# IGP-M              -0.460461  0.398003  1.000000  0.435590          0.344560
# INPC               -0.037939  0.966987  0.435590  1.000000         -0.050661
# Desemprego PNADC   -0.535693 -0.077979  0.344560 -0.050661          1.000000
